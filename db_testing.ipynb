# %%
from sqlalchemy import create_engine
import sqlite3
import pandas as pd
from tqdm import tqdm

# %%
### Create database connection

engine = create_engine(f'sqlite:///quotes.db', echo=False, connect_args={"timeout": 30})
con = sqlite3.connect('database/quotes.db') # connecting to the database
cursor = con.cursor()

# %%
### Get list of tables from database

tables = cursor.execute("SELECT name FROM sqlite_master where type='table';").fetchall() # getting every table name
tables = [table[0] for table in tables]
tables
# Out:
# ['Koutetsujou_no_Kabaneri_quotes',
#  'Mashle_quotes',
#  'Helck_quotes',
#  'Dou_Po_Cangqiong_Di_Si_Ji_quotes',
#  'Iya_na_Kao_Sarenagara_Opantsu_Misete_Moraitai_quotes',
#  'Yubisaki_to_Renren_quotes',
#  'Shokugeki_no_Souma_OAD_quotes',
#  'Sasaki_to_P-chan_quotes',
#  'Kekkon_Yubiwa_Monogatari_quotes',
#  'Nozomanu_Fushi_no_Boukensha_quotes',
#  'Isekai_Maou_to_Shoukan_Shoujo_no_Dorei_Majutsu_quotes',
#  'Isekai_Maou_to_Shoukan_Shoujo_no_Dorei_Majutsu_Omega_quotes',
#  'Magical_Hat_quotes',
#  'Aho_Girl_quotes',
#  'Kaitou_Saint_Tail_quotes',
#  'Megami_no_Cafe_Terrace_quotes',
#  'World_Trigger_quotes',
#  'Kasumin_1st_Series_quotes',
#  'Spy_x_Family_(2023)_quotes',
#  'Tensei_Shitara_Slime_Datta_Ken_(2021)_quotes',
#  'Undead_Unluck_quotes',
#  'Pokemon_Concierge_quotes',
#  'Yofukashi_no_Uta_quotes',
#  'Pon_no_Michi_quotes',
#  'Jujutsu_Kaisen_(2023)_quotes',
#  'Kage_no_Jitsuryokusha_ni_Naritakute!_2nd_Season_quotes',
#  'Shiguang_Dailiren_II_quotes',
#  'Pluto_quotes',
#  'Watashi_no_Shiawase_na_Kekkon_quotes',
#  'Fruits_Basket_1st_Season_quotes',
#  'Spy_x_Family_(2022)_quotes',
#  'Vinland_Saga_Season_2_quotes',
#  'Synduality_Noir_(2024)_quotes',
#  'Shingeki_no_Kyojin_Season_3_quotes',
#  'Shingeki_no_Kyojin_Season_3_(2019)_quotes',
#  'Shingeki_no_Kyojin_Season_2_quotes',
#  'Shingeki_no_Kyojin_OAD_quotes',
#  'Overlord_IV_quotes',
#  'Overlord_III_quotes',
#  'Overlord_II_quotes',
#  'Overlord_quotes',
#  'Kekkai_Sensen_&_Beyond_quotes',
#  'Kekkai_Sensen_quotes',
#  'Isekai_Shoukan_wa_Nidome_Desu_quotes',
#  'Fruits_Basket_2nd_Season_quotes',
#  'Double_Decker!_Doug_&_Kirill_quotes',
#  'Fruits_Basket_the_Final_quotes',
#  'Gakusen_Toshi_Asterisk_quotes',
#  'Akuma-kun_quotes',
#  'Ore_dake_Level_Up_na_Ken_quotes',
#  'Mahou_Shoujo_ni_Akogarete_quotes',
#  'Megaton-kyuu_Musashi_quotes',
#  'Undead_Girl_Murder_Farce_quotes',
#  'Captain_Tsubasa_(2018)_quotes',
#  'Boku_no_Hero_Academia_(2017)_quotes',
#  'Kono_Healer,_Mendokusai_quotes',
#  'Itai_no_wa_Iya_nano_de_Bougyoryoku_ni_Kyokufuri_Shitai_to_Omoimasu._2_quotes',
#  'Kusuriya_no_Hitorigoto_quotes',
#  'Human_Bug_Daigaku_quotes',
#  'UFO_Robo_Grendizer_quotes',
#  'Amaama_to_Inazuma_quotes',
#  'Dou_Shen_Ji_quotes',
#  'Zuihou_De_Zhaohuan_Shi_quotes',
#  'Oishinbo_quotes',
#  'Ragna_Crimson_quotes',
#  'Sousou_no_Frieren_quotes',
#  'Zanting!_Rang_Wo_Cha_Gonglue_quotes',
#  '86_quotes',
#  'Sangatsu_no_Lion_quotes',
#  'Sangatsu_no_Lion_(2017)_quotes',
#  '30-sai_made_Doutei_da_to_Mahou_Tsukai_ni_Nareru_Rashii_quotes',
#  'Shenmue_the_Animation_quotes',
#  'Yonin_wa_Sorezore_Uso_o_Tsuku_quotes',
#  'Shin_Ikkitousen_quotes',
#  'Fumetsu_no_Anata_e_quotes',
#  'Zombie_Land_Saga_Revenge_quotes',
#  'Dosanko_Gal_wa_Namara_Menkoi_quotes',
#  'Mahou_no_Princess_Minky_Momo_quotes',
#  'Waccha_PriMagi!_quotes',
#  'Shinigami_Bocchan_to_Kuro_Maid_quotes',
#  'Shinigami_Bocchan_to_Kuro_Maid_(2023)_quotes',
#  'Futari_wa_Precure_quotes',
#  'Hakuouki_quotes',
#  'Hirogaru_Sky!_Precure_quotes',
#  "Healin'_Good_Precure_quotes",
#  'Tropical-Rouge!_Precure_quotes',
#  'Meikyuu_Black_Company_quotes',
#  'Sabikui_Bisco_quotes',
#  'Tsuki_ga_Michibiku_Isekai_Douchuu_quotes',
#  'Kyoukai_no_Rinne_(2017)_quotes',
#  'High_School_Fleet_quotes',
#  'Yuru_Camp_Season_2_quotes',
#  'Elfen_Lied_quotes',
#  'Jigokuraku_quotes',
#  'Xian_Wang_de_Richang_Shenghuo_Di_Si_Ji_quotes',
#  'Majo_to_Yajuu_quotes',
#  'Hoshikuzu_Telepath_quotes',
#  'Haikara-san_ga_Tooru_quotes',
#  'Tomo-chan_wa_Onnanoko!_quotes',
#  'Otome_Game_no_Hametsu_Flag_shika_Nai_Akuyaku_Reijou_ni_Tensei_Shiteshimatta..._X_quotes',
#  '100-man_no_Inochi_no_Ue_ni_Ore_wa_Tatte_Iru_(2021)_quotes',
#  '100-man_no_Inochi_no_Ue_ni_Ore_wa_Tatte_Iru_quotes',
#  'Snack_Basue_quotes',
#  'Tensei_Shitara_Slime_Datta_Ken_(2019)_quotes',
#  'Araiguma_Rascal_quotes',
#  'Magical_Taruruuto-kun_quotes',
#  'Edens_Zero_(2023)_quotes',
#  'Ishura_quotes',
#  'Tensei_Shitara_Slime_Datta_Ken_quotes',
#  'Chiyu_Mahou_no_Machigatta_Tsukaikata_quotes',
#  '07-Ghost_quotes',
#  'Kidou_Senshi_Gundam_Double_O_quotes',
#  'Youkoso_Jitsuryoku_Shijou_Shugi_no_Kyoushitsu_e_3rd_Season_quotes',
#  'Metallic_Rouge_quotes',
#  'Made_in_Abyss_quotes',
#  'Futoku_no_Guild_quotes',
#  'Mahou_no_Idol_Pastel_Yumi_quotes',
#  'Fantasy_Bishoujo_Juniku_Ojisan_to_quotes',
#  'Grand_Blue_quotes',
#  'Ousama_Ranking_quotes',
#  'Granblue_Fantasy_The_Animation_quotes',
#  'Minami_no_Niji_no_Lucy_quotes',
#  'Shoujo_Kageki_Revue_Starlight_quotes',
#  'tables']

# %%
### Calculate percentage of unknown character rows

data=[]
for table in tables: # for each table calculate the percentage of unknown character entries
    try:
        unknown_rate=cursor.execute(f"SELECT AVG(is_unknown) \
                                    FROM \
                                        (SELECT Episode, \
                                        (CASE WHEN name IS 'Unknown' THEN 1 ELSE 0 END) AS is_unknown, \
                                        Quote FROM {table}) AS temp").fetchall()
        data.append([table,unknown_rate[0][0]])
    except:
        data.append([table, 'NaN'])

#Write it to the db

df = pd.DataFrame(data=data, columns=['name', 'unknown_rate'])
df.to_sql('tables',con=engine,if_exists='replace', index=False) # load to quotes.db
# Out:
# 124

# %%
### Clean the database

data=[]
condition = "'%{\pos%'"
for table in tables: # for each table calculate the percentage of unknown character entries
    try:
        brackets_count = cursor.execute(f"SELECT COUNT(*) FROM ( \
                                        SELECT * FROM {table} \
                                        WHERE quote LIKE {condition} \
                                        ) AS temp").fetchall()
        data.append([table,brackets_count[0][0]])
    except:
        data.append([table, 'NaN'])

data
# Out:
# [['Koutetsujou_no_Kabaneri_quotes', 0],
#  ['Mashle_quotes', 0],
#  ['Helck_quotes', 0],
#  ['Dou_Po_Cangqiong_Di_Si_Ji_quotes', 0],
#  ['Iya_na_Kao_Sarenagara_Opantsu_Misete_Moraitai_quotes', 0],
#  ['Yubisaki_to_Renren_quotes', 0],
#  ['Shokugeki_no_Souma_OAD_quotes', 0],
#  ['Sasaki_to_P-chan_quotes', 'NaN'],
#  ['Kekkon_Yubiwa_Monogatari_quotes', 0],
#  ['Nozomanu_Fushi_no_Boukensha_quotes', 0],
#  ['Isekai_Maou_to_Shoukan_Shoujo_no_Dorei_Majutsu_quotes', 0],
#  ['Isekai_Maou_to_Shoukan_Shoujo_no_Dorei_Majutsu_Omega_quotes', 0],
#  ['Magical_Hat_quotes', 0],
#  ['Aho_Girl_quotes', 0],
#  ['Kaitou_Saint_Tail_quotes', 0],
#  ['Megami_no_Cafe_Terrace_quotes', 0],
#  ['World_Trigger_quotes', 0],
#  ['Kasumin_1st_Series_quotes', 0],
#  ['Spy_x_Family_(2023)_quotes', 'NaN'],
#  ['Tensei_Shitara_Slime_Datta_Ken_(2021)_quotes', 'NaN'],
#  ['Undead_Unluck_quotes', 0],
#  ['Pokemon_Concierge_quotes', 0],
#  ['Yofukashi_no_Uta_quotes', 0],
#  ['Pon_no_Michi_quotes', 0],
#  ['Jujutsu_Kaisen_(2023)_quotes', 'NaN'],
#  ['Kage_no_Jitsuryokusha_ni_Naritakute!_2nd_Season_quotes', 'NaN'],
#  ['Shiguang_Dailiren_II_quotes', 0],
#  ['Pluto_quotes', 0],
#  ['Watashi_no_Shiawase_na_Kekkon_quotes', 0],
#  ['Fruits_Basket_1st_Season_quotes', 0],
#  ['Spy_x_Family_(2022)_quotes', 'NaN'],
#  ['Vinland_Saga_Season_2_quotes', 0],
#  ['Synduality_Noir_(2024)_quotes', 'NaN'],
#  ['Shingeki_no_Kyojin_Season_3_quotes', 0],
#  ['Shingeki_no_Kyojin_Season_3_(2019)_quotes', 'NaN'],
#  ['Shingeki_no_Kyojin_Season_2_quotes', 0],
#  ['Shingeki_no_Kyojin_OAD_quotes', 0],
#  ['Overlord_IV_quotes', 0],
#  ['Overlord_III_quotes', 0],
#  ['Overlord_II_quotes', 0],
#  ['Overlord_quotes', 0],
#  ['Kekkai_Sensen_&_Beyond_quotes', 'NaN'],
#  ['Kekkai_Sensen_quotes', 0],
#  ['Isekai_Shoukan_wa_Nidome_Desu_quotes', 0],
#  ['Fruits_Basket_2nd_Season_quotes', 0],
#  ['Double_Decker!_Doug_&_Kirill_quotes', 'NaN'],
#  ['Fruits_Basket_the_Final_quotes', 0],
#  ['Gakusen_Toshi_Asterisk_quotes', 0],
#  ['Akuma-kun_quotes', 'NaN'],
#  ['Ore_dake_Level_Up_na_Ken_quotes', 0],
#  ['Mahou_Shoujo_ni_Akogarete_quotes', 0],
#  ['Megaton-kyuu_Musashi_quotes', 'NaN'],
#  ['Undead_Girl_Murder_Farce_quotes', 0],
#  ['Captain_Tsubasa_(2018)_quotes', 'NaN'],
#  ['Boku_no_Hero_Academia_(2017)_quotes', 'NaN'],
#  ['Kono_Healer,_Mendokusai_quotes', 'NaN'],
#  ['Itai_no_wa_Iya_nano_de_Bougyoryoku_ni_Kyokufuri_Shitai_to_Omoimasu._2_quotes',
#   'NaN'],
#  ['Kusuriya_no_Hitorigoto_quotes', 0],
#  ['Human_Bug_Daigaku_quotes', 0],
#  ['UFO_Robo_Grendizer_quotes', 0],
#  ['Amaama_to_Inazuma_quotes', 0],
#  ['Dou_Shen_Ji_quotes', 0],
#  ['Zuihou_De_Zhaohuan_Shi_quotes', 0],
#  ['Oishinbo_quotes', 0],
#  ['Ragna_Crimson_quotes', 0],
#  ['Sousou_no_Frieren_quotes', 0],
#  ['Zanting!_Rang_Wo_Cha_Gonglue_quotes', 'NaN'],
#  ['86_quotes', 'NaN'],
#  ['Sangatsu_no_Lion_quotes', 0],
#  ['Sangatsu_no_Lion_(2017)_quotes', 'NaN'],
#  ['30-sai_made_Doutei_da_to_Mahou_Tsukai_ni_Nareru_Rashii_quotes', 'NaN'],
#  ['Shenmue_the_Animation_quotes', 0],
#  ['Yonin_wa_Sorezore_Uso_o_Tsuku_quotes', 0],
#  ['Shin_Ikkitousen_quotes', 0],
#  ['Fumetsu_no_Anata_e_quotes', 0],
#  ['Zombie_Land_Saga_Revenge_quotes', 0],
#  ['Dosanko_Gal_wa_Namara_Menkoi_quotes', 0],
#  ['Mahou_no_Princess_Minky_Momo_quotes', 0],
#  ['Waccha_PriMagi!_quotes', 'NaN'],
#  ['Shinigami_Bocchan_to_Kuro_Maid_quotes', 0],
#  ['Shinigami_Bocchan_to_Kuro_Maid_(2023)_quotes', 'NaN'],
#  ['Futari_wa_Precure_quotes', 0],
#  ['Hakuouki_quotes', 0],
#  ['Hirogaru_Sky!_Precure_quotes', 'NaN'],
#  ["Healin'_Good_Precure_quotes", 'NaN'],
#  ['Tropical-Rouge!_Precure_quotes', 'NaN'],
#  ['Meikyuu_Black_Company_quotes', 0],
#  ['Sabikui_Bisco_quotes', 0],
#  ['Tsuki_ga_Michibiku_Isekai_Douchuu_quotes', 0],
#  ['Kyoukai_no_Rinne_(2017)_quotes', 'NaN'],
#  ['High_School_Fleet_quotes', 0],
#  ['Yuru_Camp_Season_2_quotes', 0],
#  ['Elfen_Lied_quotes', 0],
#  ['Jigokuraku_quotes', 0],
#  ['Xian_Wang_de_Richang_Shenghuo_Di_Si_Ji_quotes', 0],
#  ['Majo_to_Yajuu_quotes', 0],
#  ['Hoshikuzu_Telepath_quotes', 0],
#  ['Haikara-san_ga_Tooru_quotes', 'NaN'],
#  ['Tomo-chan_wa_Onnanoko!_quotes', 'NaN'],
#  ['Otome_Game_no_Hametsu_Flag_shika_Nai_Akuyaku_Reijou_ni_Tensei_Shiteshimatta..._X_quotes',
#   'NaN'],
#  ['100-man_no_Inochi_no_Ue_ni_Ore_wa_Tatte_Iru_(2021)_quotes', 'NaN'],
#  ['100-man_no_Inochi_no_Ue_ni_Ore_wa_Tatte_Iru_quotes', 'NaN'],
#  ['Snack_Basue_quotes', 0],
#  ['Tensei_Shitara_Slime_Datta_Ken_(2019)_quotes', 'NaN'],
#  ['Araiguma_Rascal_quotes', 0],
#  ['Magical_Taruruuto-kun_quotes', 'NaN'],
#  ['Edens_Zero_(2023)_quotes', 'NaN'],
#  ['Ishura_quotes', 0],
#  ['Tensei_Shitara_Slime_Datta_Ken_quotes', 0],
#  ['Chiyu_Mahou_no_Machigatta_Tsukaikata_quotes', 0],
#  ['07-Ghost_quotes', 'NaN'],
#  ['Kidou_Senshi_Gundam_Double_O_quotes', 0],
#  ['Youkoso_Jitsuryoku_Shijou_Shugi_no_Kyoushitsu_e_3rd_Season_quotes', 0],
#  ['Metallic_Rouge_quotes', 0],
#  ['Made_in_Abyss_quotes', 0],
#  ['Futoku_no_Guild_quotes', 0],
#  ['Mahou_no_Idol_Pastel_Yumi_quotes', 0],
#  ['Fantasy_Bishoujo_Juniku_Ojisan_to_quotes', 0],
#  ['Grand_Blue_quotes', 0],
#  ['Ousama_Ranking_quotes', 0],
#  ['Granblue_Fantasy_The_Animation_quotes', 0],
#  ['Minami_no_Niji_no_Lucy_quotes', 0],
#  ['Shoujo_Kageki_Revue_Starlight_quotes', 0],
#  ['tables', 'NaN']]

# %%
condition = "'%{\pos%'" # condition to delete row
for table in tqdm(tables): # for each table delete quote entries like {\pos} usually they are from opening or name of sub provider
    try:
        result = cursor.execute(f"DELETE FROM {table} WHERE quote LIKE {condition}") # delete quotes where
        con.commit() # commit changes
        print(cursor.rowcount) # get how many rows were affected
    except:
        print('error', table, result)
        pass
